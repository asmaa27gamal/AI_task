# %%
#Q1
import pandas as pd
dataset=pd.read_csv("Wuzzuf_Jobs.csv")
dataset.head()
# Out:
#                                Title                Company    Location  \
# 0             Customer Service Agent       Johnson Controls   New Cairo
# 1                  Marketing Manager  SYE English Community       Dokki
# 2  Medical Representative Heliopolis        So Value Pharma       Cairo
# 3          Order Handling Specialist       Johnson Controls   New Cairo
# 4                        Storekeeper           Confidential       Cairo
#
#         Type        Level         YearsExp Country  \
# 0  Full Time  Entry Level   1-3 Yrs of Exp   Cairo
# 1  Full Time      Manager  5-10 Yrs of Exp    Giza
# 2  Full Time  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Full Time  Experienced   3-5 Yrs of Exp   Cairo
# 4  Full Time  Experienced    3+ Yrs of Exp   Egypt
#
#                                               Skills
# 0  Call Center, Customer Support, Customer Care, ...
# 1  Market Research, Social Media, Online Marketin...
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...
# ...

# %%
#Q2
dataset.shape
# Out:
# (4380, 8)

# %%
#Q3
import pandas as pd

# making data frame from csv file
data = pd.read_csv("Wuzzuf_Jobs.csv")

# sorting by first name
data.sort_values("Level", inplace = True)

# dropping ALL duplicate values
data.drop_duplicates(subset ="Level",
keep = "first", inplace = True)

# displaying data
data
# Out:
#                                             Title  \
# 0                          Customer Service Agent
# 4348                   Senior Property Consultant
# 966              Photo Editor - Design Background
# 141                Supply Chain Operation Manager
# 49                           Marketing Specialist
# 437                           HC & Admin Director
# 2805  Medical Approval / Customer Success Officer
# 1140                Graphic Designer - Internship
# 73                           Curriculum Developer
#
#                             Company     Location        Type  \
# 0                  Johnson Controls    New Cairo   Full Time
# 4348           Pillarz Developments   Heliopolis   Full Time
# 966                    Confidential   Alexandria   Full Time
# 141                    Confidential        Maadi   Full Time
# 49                 Sparks preschool    New Cairo   Full Time
# 437                    Bingo Global     Sheraton   Full Time
# ...

# %%
#Q3

data.sort_values("Title",inplace=True)
data.drop_duplicates(subset='Title',keep="first",inplace=True)
data
# Out:
#                                             Title  \
# 73                           Curriculum Developer
# 0                          Customer Service Agent
# 1140                Graphic Designer - Internship
# 437                           HC & Admin Director
# 49                           Marketing Specialist
# 2805  Medical Approval / Customer Success Officer
# 966              Photo Editor - Design Background
# 4348                   Senior Property Consultant
# 141                Supply Chain Operation Manager
#
#                             Company     Location        Type  \
# 73             Almotahida Education        Cairo   Full Time
# 0                  Johnson Controls    New Cairo   Full Time
# 1140  Businessita Women Empowerment        Cairo  Internship
# 437                    Bingo Global     Sheraton   Full Time
# 49                 Sparks preschool    New Cairo   Full Time
# 2805                Beyond Solution        Maadi   Full Time
# ...

# %%
dataset.dropna()
# Out:
#                                                  Title           Company  \
# 3410                   .NET Angular Software Developer             Xceed
# 2859                       .NET Back-End Web Developer      Confidential
# 3074                                    .NET Developer      Dynamicslink
# 1717                                    .NET Developer  Beta Electronics
# 2862              .NET Developer (Desktop Application)      Confidential
# ...                                                ...               ...
# 51                                  فنى صيانة ميكانيكا        EL SHIDEED
# 2481        مدير تنفيذ - Operations Director (Civil...              Agec
# 2561  مراجع لغة عربية - Arabic Proofreader (Hindawi...             Nagwa
# 673                             مسؤول إدارة المستفيدين      Mishkat Nour
# 495                            مندوب تحصيل - Collector           BituNil
#
#          Location       Type        Level         YearsExp Country  \
# ...

# %%
#Q4
dataset['Skills']
Skill=dataset['Skills'].value_counts()
print(Skill)
data.sort_values("Skills", inplace = True)
# Out:
# Corporate Sales, Real Estate, Advertising, Marketing, Sales Skills, Insurance, Sales Target, Outdoor Sales, Telesales, Property          12
# Logistics, SAP, Inventory, Store Keeping, Logistics/Supply Chain                                                                         11
# Sales Skills, Sales Target, Customer Services, Customer Care, Retail, Collection, Distribution, Selling Skills, Negotiation Skills       10
# Medical, Training, Family Palnning, Contraceptives, MoHP, Medical/Healthcare, Training/Instructor                                         9
# Finance, Sales Accounting, Commerce, Budget, Reporting, Accounting/Finance                                                                9
#                                                                                                                                          ..
# Information Technology (IT), Software Development, Mobile Development, Android Developer, IT/Software Development                         1
# ...

# %%
#Q4
jobs=dataset['Title'].value_counts()
dataset.sort_values("Title",inplace= True)
print(jobs)
# Out:
# Accountant                              57
# Sales Representative                    47
# Graphic Designer                        43
# Digital Marketing Specialist            26
# Social Media Specialist                 25
#                                         ..
# Senior IT Specialist (Helpdesk)          1
# Advising Program Officer                 1
# CRM Officer                              1
# Front Office Representative              1
# Mobile Sales Representative (Indoor)     1
# Name: Title, Length: 2965, dtype: int64

# %%
#Q5
import matplotlib.pyplot as plt
plt.pie(jobs)  
plt.show()

# %%
#Q6
Skills=data['Title'].value_counts()
print(Skills)
# Out:
# Photo Editor - Design Background               1
# Graphic Designer - Internship                  1
# Curriculum Developer                           1
# Supply Chain Operation Manager                 1
# Senior Property Consultant                     1
# Customer Service Agent                         1
# HC & Admin Director                            1
# Marketing Specialist                           1
# Medical Approval / Customer Success Officer    1
# Name: Title, dtype: int64

# %%
# Q7
# bar chart for title 

data2= {'Xceed ':'    .NET Angular Software Developer', 'Confidential':'  .NET Back-End Web Developer', 'IKEN Technology':'  .NET Developer - Internship',
		'Obeikan Digital Solutions':'  .Net Core Developer'}
Company = list(data2.keys())
Title = list(data2.values())

plt.bar(Company, Title, color ='maroon',
		width = 0.6)

plt.xlabel("company name ")
plt.ylabel("Title of jobs")
plt.title("jobs in different companies")
plt.show()

# %%
#Q8
Location=data['Location'].value_counts()
print(Location)
# Out:
#  Maadi         2
#  New Cairo     2
#  Cairo         2
#  Alexandria    1
#  Heliopolis    1
#  Sheraton      1
# Name: Location, dtype: int64

# %%
# Q9
# bar chart for title 

data1= {'Xceed ':'  New Cairo', 'Confidential':'  Maadi', 'IKEN Technology':'   Nasr City','Obeikan Digital Solutions':'   Alexandria'}
Company = list(data2.keys())
Location = list(data2.values())

plt.bar(Company, Location, color ='maroon',width = 0.6)

plt.xlabel("company name ")
plt.ylabel("Location of jobs")
plt.title("jobs in different companies")
plt.show()

# %%
#Q10
skill=dataset['Skills'].value_counts()
dataset.sort_values("Skills", inplace = True)

# to convert skills column into list 
skill=dataset.Skills.tolist()
for skill in skill :
    print(skill)
    print ()
# Out:
# .NET Core, Bootstrap, javaScript, Software Development, HTML, CSS, Information Technology (IT), IT/Software Development
#
# .NET Development, Computer Science, Computer Engineering, Information Technology (IT), C#, MVC, ASP.NET, Angular, Typescript, HTML5
#
# .NET, Angular, Information Technology (IT), Software Development, CSS, Computer Science, javaScript, Front-End, MongoDB, MySQL
#
# .NET, Communication Skills, Managerial Skills, Information Technology (IT), Computer Science, Programming, Software Engineering
#
# .NET, MVC, C#, TFS, Git, Software Development, Information Technology (IT), Computer Science, IT/Software Development
#
# .NET, javaScript, Computer Science, Information Technology (IT), PHP, Angular, HTML, CSS, SQL, React, XML
#
# 0-1 Yrs of Exp, 10 Vacancies, Pharmacy, Science, Beauty, Cosmetics, Gulf Area, R&D/Science, Customer Service/Support
#
# 0-2 Yrs of Exp, 2 Vacancies, Languages, Linguistics, Training, Translation, Instructor, Education, IQP, Teaching
#
# ...
